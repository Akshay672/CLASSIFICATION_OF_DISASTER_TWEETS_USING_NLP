# %% [markdown]
# # Classification on Disaster Tweets

# %% [markdown]
# ## Context
#
# The file contains over 11,000 tweets associated with disaster keywords like “crash”, “quarantine”, and “bush fires” as well as the location and keyword itself. The data structure was inherited from Disasters on social media
#
# The tweets were collected on Jan 14th, 2020.
#
# ### Some of the topics people were tweeting:
#
# The eruption of Taal Volcano in Batangas, Philippines
# Coronavirus
# Bushfires in Australia
# Iran downing of the airplane flight PS752
# Disclaimer: The dataset contains text that may be considered profane, vulgar, or offensive.

# %%
#Kaggle Link :https://www.kaggle.com/vstepanenko/disaster-tweets

# %%
#importing libraries

# %%
import numpy as np
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
#Rest of the libarires will be imported wehere ever necessary

# %%
#Reading the dataset

# %%
df=pd.read_csv('D:\\M. Tech in Data Science & Machine Learning\\Natural language processing (NLP)\\Sem Preparation\\Disaster Tweets\\tweets.csv')
df.head()#reading first 5 observations
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0

# %%
df.tail()#reading last 5 observations
# Out:
#           id  keyword                 location  \
# 11365  11365  wrecked  Blue State in a red sea
# 11366  11366  wrecked               arohaonces
# 11367  11367  wrecked                       🇵🇭
# 11368  11368  wrecked           auroraborealis
# 11369  11369  wrecked                      NaN
#
#                                                     text  target
# 11365  Media should have warned us well in advance. T...       0
# 11366  i feel directly attacked 💀 i consider moonbin ...       0
# 11367  i feel directly attacked 💀 i consider moonbin ...       0
# 11368  ok who remember "outcast" nd the "dora" au?? T...       0
# 11369     Jake Corway wrecked while running 14th at IRP.       1

# %%
df.shape #11370 records and 5 features in total including target variable
# Out:
# (11370, 5)

# %%
df.info()#summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11370 entries, 0 to 11369
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        11370 non-null  int64
#  1   keyword   11370 non-null  object
#  2   location  7952 non-null   object
#  3   text      11370 non-null  object
#  4   target    11370 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 444.3+ KB

# %%
#inferences:

#2 features are numeric and 3 features are categorical

# %%
df1=df.iloc[:,3:]#only selecting the siginfact variables for our analysis
df1.head()
# Out:
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0

# %%
#cleaning of the Data

# %%
#1. Lowercase and Replace

# %%
##remove everything other than ^a-z\s
#^a-z:lowe case alphabets
#\s:space

# %%
df1['text_clean']=df1['text'].str.lower().str.replace('[^a-z\s]','')
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  communal violence in bhainsa telangana stones ...
# 1  telangana section  has been imposed in bhainsa...
# 2  arsonist sets cars ablaze at dealership httpst...
# 3  arsonist sets cars ablaze at dealership httpst...
# 4  lord jesus your love brings freedom and pardon...

# %%
#2. Tokenize

# %%
#In Python tokenization basically refers to splitting up a larger body of text into smaller lines, 
#words or even creating words for a non-English language

# %%
df1['text_clean']=df1['text_clean'].str.split(' ')
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  [communal, violence, in, bhainsa, telangana, s...
# 1  [telangana, section, , has, been, imposed, in,...
# 2  [arsonist, sets, cars, ablaze, at, dealership,...
# 3  [arsonist, sets, cars, ablaze, at, dealership,...
# 4  [lord, jesus, your, love, brings, freedom, and...

# %%
#3. Removing Stopwords

# %%
import nltk

# %%
#Stopwords are the English words which does not add much meaning to a sentence.

# %%
common_Stopwords=nltk.corpus.stopwords.words('english')
print(common_Stopwords)#dowladed the common stopwords from nltk library
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
len(common_Stopwords)
# Out:
# 179

# %%
common_Stopwords.remove('no')
common_Stopwords.remove('nor')
common_Stopwords.remove('not')

# %%
len(common_Stopwords)#some words have been removed
# Out:
# 176

# %%
def drop_stopwords(text):
    return [word for word in text if word not in common_Stopwords]

# %%
df1['text_clean']=df1['text_clean'].apply(drop_stopwords)
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  [communal, violence, bhainsa, telangana, stone...
# 1  [telangana, section, , imposed, bhainsa, janua...
# 2  [arsonist, sets, cars, ablaze, dealership, htt...
# 3  [arsonist, sets, cars, ablaze, dealership, htt...
# 4  [lord, jesus, love, brings, freedom, pardon, f...

# %%
#4. Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer
Lemmatization=WordNetLemmatizer()

# %%
def lemmatization(text):
    return [Lemmatization.lemmatize(word) for word in text]

# %%
df1['text_clean']=df1['text_clean'].apply(lemmatization)
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  [communal, violence, bhainsa, telangana, stone...
# 1  [telangana, section, , imposed, bhainsa, janua...
# 2  [arsonist, set, car, ablaze, dealership, https...
# 3  [arsonist, set, car, ablaze, dealership, https...
# 4  [lord, jesus, love, brings, freedom, pardon, f...

# %%
#5. Clean the text

# %%
df1['text_clean']=df1['text_clean'].apply(lambda x: ' '.join(x))
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  communal violence bhainsa telangana stone pelt...
# 1  telangana section  imposed bhainsa january   c...
# 2  arsonist set car ablaze dealership httpstcogoq...
# 3  arsonist set car ablaze dealership httpstcogln...
# 4  lord jesus love brings freedom pardon fill hol...

# %%
#checking the target variable

# %%
df1['target'].value_counts()
# Out:
# 0    9256
# 1    2114
# Name: target, dtype: int64

# %%
##Vectorizing

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
Tfidf=TfidfVectorizer(max_features=2500)

# %%
X1=Tfidf.fit_transform(df1['text_clean'])#independent Variable

# %%
Y1=df1['target']#target variable

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
x_tain,x_test,y_train,y_test=train_test_split(X1, Y1, test_size=0.15, random_state=2)

# %%
#Modelling

# %%
#1. KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knc=KNeighborsClassifier()
K_Neighbors_Classifier=knc.fit(x_tain,y_train)

# %%
knc_pred=K_Neighbors_Classifier.predict(x_test)

# %%
print(classification_report(knc_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      1640
#            1       0.20      0.91      0.33        66
#
#     accuracy                           0.85      1706
#    macro avg       0.60      0.88      0.62      1706
# weighted avg       0.96      0.85      0.90      1706

# %%
confusion_matrix(knc_pred,y_test)
# Out:
# array([[1398,  242],
#        [   6,   60]], dtype=int64)

# %%
accuracy_score(knc_pred,y_test)*100
# Out:
# 85.4630715123095

# %%
##Inference:

#Accuracy of the model is 85.63

#Precison of the model is high amlost 0.62

#TPR(true positive rate) ie, Recall is also high 0.84

# %%
#2. Support Vector machine

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
Support_Vector_machine=svc.fit(x_tain,y_train)

# %%
svm_pred=Support_Vector_machine.predict(x_test)

# %%
print(classification_report(svm_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.90      0.94      1544
#            1       0.47      0.88      0.61       162
#
#     accuracy                           0.89      1706
#    macro avg       0.73      0.89      0.78      1706
# weighted avg       0.94      0.89      0.91      1706

# %%
confusion_matrix(svm_pred,y_test)
# Out:
# array([[1384,  160],
#        [  20,  142]], dtype=int64)

# %%
accuracy_score(svm_pred,y_test)*100
# Out:
# 89.44900351699883

# %%
##Inference:

#Accuracy of the model is 89.44

#Precison of the model is high amlost 0.72

#TPR(true positive rate) ie, Recall is also high 0.89

# %%
#3. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
DecisionTree_Classifier=dtc.fit(x_tain,y_train)

# %%
dtc_pred=DecisionTree_Classifier.predict(x_test)

# %%
print(classification_report(dtc_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1425
#            1       0.59      0.64      0.61       281
#
#     accuracy                           0.87      1706
#    macro avg       0.76      0.78      0.77      1706
# weighted avg       0.87      0.87      0.87      1706

# %%
confusion_matrix(dtc_pred,y_test)
# Out:
# array([[1302,  123],
#        [ 102,  179]], dtype=int64)

# %%
accuracy_score(dtc_pred,y_test)*100
# Out:
# 86.81125439624854

# %%
##Inference:

#Accuracy of the model is 86.98

#Precison of the model is high amlost 0.75

#TPR(true positive rate) ie, Recall is also high 0.78

# %%
#4. Random Forest Classifier (bagging)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()
Random_Forest_Classifier=rfc.fit(x_tain,y_train)

# %%
rfc_pred=Random_Forest_Classifier.predict(x_test)

# %%
print(classification_report(rfc_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93      1500
#            1       0.53      0.77      0.63       206
#
#     accuracy                           0.89      1706
#    macro avg       0.75      0.84      0.78      1706
# weighted avg       0.91      0.89      0.90      1706

# %%
confusion_matrix(rfc_pred,y_test)
# Out:
# array([[1357,  143],
#        [  47,  159]], dtype=int64)

# %%
accuracy_score(rfc_pred,y_test)*100
# Out:
# 88.862837045721

# %%
##Inference:

#Accuracy of the model is 89.39

#Precison of the model is high amlost 0.76

#TPR(true positive rate) ie, Recall is also high 0.84

# %%
#5. AdaBoostClassifier (Boosting)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()
Ada_Boost_Classifier=ada.fit(x_tain,y_train)

# %%
ada_pred=Ada_Boost_Classifier.predict(x_test)

# %%
print(classification_report(ada_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91      1549
#            1       0.34      0.65      0.44       157
#
#     accuracy                           0.85      1706
#    macro avg       0.65      0.76      0.68      1706
# weighted avg       0.90      0.85      0.87      1706

# %%
confusion_matrix(ada_pred,y_test)
# Out:
# array([[1349,  200],
#        [  55,  102]], dtype=int64)

# %%
accuracy_score(ada_pred,y_test)*100
# Out:
# 85.052754982415

# %%
##Inference:

#Accuracy of the model is 85.52

#Precison of the model is high amlost 0.66

#TPR(true positive rate) ie, Recall is also high 0.78

# %%
#6. GradientBoostingClassifier (Boosting)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()
Gradient_Boosting_Classifier=gbc.fit(x_tain,y_train)

# %%
gbc_pred=Gradient_Boosting_Classifier.predict(x_test)

# %%
print(classification_report(gbc_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92      1629
#            1       0.22      0.84      0.34        77
#
#     accuracy                           0.85      1706
#    macro avg       0.60      0.85      0.63      1706
# weighted avg       0.96      0.85      0.89      1706

# %%
confusion_matrix(gbc_pred,y_test)
# Out:
# array([[1392,  237],
#        [  12,   65]], dtype=int64)

# %%
accuracy_score(gbc_pred,y_test)*100
# Out:
# 85.4044548651817

# %%
##Inference:

#Accuracy of the model is 85.11

#Precison of the model is high amlost 0.60

#TPR(true positive rate) ie, Recall is also high 0.84

# %%
#7. XGBClassifier:xgboost classifier (Boosting)

# %%
#!pip install xgboost

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()
XGB_Classifier=xgb.fit(x_tain,y_train)
# Out:
# [19:26:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
xgb_pred=XGB_Classifier.predict(x_test)

# %%
print(classification_report(xgb_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93      1561
#            1       0.39      0.81      0.52       145
#
#     accuracy                           0.88      1706
#    macro avg       0.68      0.84      0.73      1706
# weighted avg       0.93      0.88      0.89      1706

# %%
confusion_matrix(xgb_pred,y_test)
# Out:
# array([[1376,  185],
#        [  28,  117]], dtype=int64)

# %%
accuracy_score(xgb_pred,y_test)*100
# Out:
# 87.51465416178195

# %%
#LSTM

# %%
#Long Short-Term Memory (LSTM) networks are a type of recurrent neural network capable of learning order dependence in sequence prediction problems.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df1.head()
# Out:
#                                                 text  target  \
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0
#
#                                           text_clean
# 0  communal violence bhainsa telangana stone pelt...
# 1  telangana section  imposed bhainsa january   c...
# 2  arsonist set car ablaze dealership httpstcogoq...
# 3  arsonist set car ablaze dealership httpstcogln...
# 4  lord jesus love brings freedom pardon fill hol...

# %%
vocabSize=2500
tokenizer = Tokenizer(num_words=vocabSize,split=' ')#split on space
tokenizer.fit_on_texts(df1['text_clean'].values)

#fit_on_texts :Updates internal vocabulary based on a list of texts. 
    #This method creates the vocabulary index based on word frequency. 
    #So if you give it something like, "The cat sat on the mat."
    #It will create a dictionary s.t. word_index["the"] = 1; word_index["cat"] = 2 it is word -> index dictionary so every word gets a unique integer value. 
    #0 is reserved for padding. So lower integer means more frequent word (often the first few are stop words because they appear a lot).

# %%
vocab_size=tokenizer.word_index#word_index
vocab_size
# Out:
# {'not': 1,
#  'amp': 2,
#  'like': 3,
#  'people': 4,
#  'fire': 5,
#  'u': 6,
#  'im': 7,
#  'no': 8,
#  'one': 9,
#  'get': 10,
#  'year': 11,
#  'dont': 12,
#  'time': 13,
#  'need': 14,
#  'day': 15,
#  'new': 16,
#  'know': 17,
#  'would': 18,
#  'say': 19,
#  'iran': 20,
#  'first': 21,
#  'see': 22,
#  'think': 23,
#  'today': 24,
#  'storm': 25,
#  'go': 26,
#  'death': 27,
#  'want': 28,
#  'still': 29,
#  'trump': 30,
#  'emergency': 31,
#  'back': 32,
#  'man': 33,
#  'world': 34,
#  'two': 35,
#  'let': 36,
#  'australia': 37,
#  'body': 38,
#  'many': 39,
#  'news': 40,
#  'make': 41,
#  'cant': 42,
#  'attack': 43,
#  'got': 44,
#  'please': 45,
#  'help': 46,
#  'good': 47,
#  'th': 48,
#  'right': 49,
#  'really': 50,
#  'also': 51,
#  'last': 52,
#  'could': 53,
#  'said': 54,
#  'much': 55,
#  'home': 56,
#  'thats': 57,
#  'come': 58,
#  'love': 59,
#  'nuclear': 60,
#  'volcano': 61,
#  'woman': 62,
#  'take': 63,
#  'killed': 64,
#  'even': 65,
#  'look': 66,
#  'never': 67,
#  'life': 68,
#  'bomb': 69,
#  'police': 70,
#  'house': 71,
#  'going': 72,
#  'service': 73,
#  'state': 74,
#  'taal': 75,
#  'thing': 76,
#  'country': 77,
#  'way': 78,
#  'building': 79,
#  'well': 80,
#  'youre': 81,
#  'air': 82,
#  'ive': 83,
#  'disaster': 84,
#  'another': 85,
#  'show': 86,
#  'suicide': 87,
#  'every': 88,
#  'bag': 89,
#  'w': 90,
#  'dead': 91,
#  'train': 92,
#  'since': 93,
#  'war': 94,
#  'part': 95,
#  'army': 96,
#  'due': 97,
#  'mass': 98,
#  'climate': 99,
#  'video': 100,
#  'road': 101,
#  'work': 102,
#  'feel': 103,
#  'flood': 104,
#  'burning': 105,
#  'heart': 106,
#  'b': 107,
#  'god': 108,
#  'didnt': 109,
#  'someone': 110,
#  'made': 111,
#  'injury': 112,
#  'hit': 113,
#  'via': 114,
#  'city': 115,
#  'area': 116,
#  'terrorist': 117,
#  'keep': 118,
#  'guy': 119,
#  'morning': 120,
#  'around': 121,
#  'family': 122,
#  'china': 123,
#  'stop': 124,
#  'child': 125,
#  'cause': 126,
#  'fear': 127,
#  'may': 128,
#  'point': 129,
#  'school': 130,
#  'government': 131,
#  'night': 132,
#  'put': 133,
#  'animal': 134,
#  'week': 135,
#  'call': 136,
#  'power': 137,
#  'must': 138,
#  'bad': 139,
#  'thunderstorm': 140,
#  'mean': 141,
#  'there': 142,
#  'remember': 143,
#  'great': 144,
#  'hour': 145,
#  'c': 146,
#  'h': 147,
#  'nothing': 148,
#  'weapon': 149,
#  'water': 150,
#  'high': 151,
#  'game': 152,
#  'case': 153,
#  'least': 154,
#  'everyone': 155,
#  'million': 156,
#  'found': 157,
#  'set': 158,
#  'change': 159,
#  'always': 160,
#  'start': 161,
#  'pm': 162,
#  'australian': 163,
#  'bombing': 164,
#  'military': 165,
#  'friend': 166,
#  'eruption': 167,
#  'live': 168,
#  'earthquake': 169,
#  'tell': 170,
#  'getting': 171,
#  'rescue': 172,
#  'ago': 173,
#  'iranian': 174,
#  'party': 175,
#  'started': 176,
#  'trying': 177,
#  'rain': 178,
#  'he': 179,
#  'read': 180,
#  'place': 181,
#  'fatality': 182,
#  'hostage': 183,
#  'smoke': 184,
#  'accident': 185,
#  'hope': 186,
#  'severe': 187,
#  'car': 188,
#  'medium': 189,
#  'force': 190,
#  'american': 191,
#  'n': 192,
#  'left': 193,
#  'south': 194,
#  'warning': 195,
#  'near': 196,
#  'watch': 197,
#  'old': 198,
#  'away': 199,
#  'next': 200,
#  'president': 201,
#  'bus': 202,
#  'collision': 203,
#  'story': 204,
#  'threat': 205,
#  'oh': 206,
#  'yet': 207,
#  'forest': 208,
#  'big': 209,
#  'used': 210,
#  'month': 211,
#  'head': 212,
#  'ever': 213,
#  'philippine': 214,
#  'january': 215,
#  'human': 216,
#  'shit': 217,
#  'real': 218,
#  'lot': 219,
#  'blood': 220,
#  'mind': 221,
#  'ill': 222,
#  'oil': 223,
#  'isnt': 224,
#  'thought': 225,
#  'r': 226,
#  'end': 227,
#  'damage': 228,
#  'team': 229,
#  'person': 230,
#  'http': 231,
#  'siren': 232,
#  'best': 233,
#  'murder': 234,
#  'without': 235,
#  'crash': 236,
#  'done': 237,
#  'bush': 238,
#  'drown': 239,
#  'save': 240,
#  'battle': 241,
#  'screaming': 242,
#  'wind': 243,
#  'plan': 244,
#  'girl': 245,
#  'doesnt': 246,
#  'fall': 247,
#  'lost': 248,
#  'anyone': 249,
#  'give': 250,
#  'wave': 251,
#  'weather': 252,
#  'hear': 253,
#  'casualty': 254,
#  'drowning': 255,
#  'little': 256,
#  'v': 257,
#  'sure': 258,
#  'alert': 259,
#  'money': 260,
#  'id': 261,
#  'yes': 262,
#  'flattened': 263,
#  'twitter': 264,
#  'report': 265,
#  'lightning': 266,
#  'p': 267,
#  'find': 268,
#  'shot': 269,
#  'across': 270,
#  'bushfires': 271,
#  'electrocute': 272,
#  'almost': 273,
#  'update': 274,
#  'already': 275,
#  'far': 276,
#  'name': 277,
#  'f': 278,
#  'gonna': 279,
#  'collapse': 280,
#  'sinkhole': 281,
#  'stretcher': 282,
#  'use': 283,
#  'long': 284,
#  'baby': 285,
#  'actually': 286,
#  'coming': 287,
#  'something': 288,
#  'try': 289,
#  'loud': 290,
#  'face': 291,
#  'heard': 292,
#  'six': 293,
#  'violent': 294,
#  'rt': 295,
#  'thank': 296,
#  'saying': 297,
#  'israel': 298,
#  'fact': 299,
#  'hurricane': 300,
#  'whole': 301,
#  'st': 302,
#  'called': 303,
#  'seen': 304,
#  'victim': 305,
#  'official': 306,
#  'literally': 307,
#  'support': 308,
#  'attacked': 309,
#  'five': 310,
#  'enough': 311,
#  'chemical': 312,
#  'obliterate': 313,
#  'india': 314,
#  'hi': 315,
#  'job': 316,
#  'open': 317,
#  'engulfed': 318,
#  'derailed': 319,
#  'national': 320,
#  'went': 321,
#  'check': 322,
#  'might': 323,
#  'airplane': 324,
#  'sorry': 325,
#  'line': 326,
#  'free': 327,
#  'white': 328,
#  'post': 329,
#  'america': 330,
#  'bloody': 331,
#  'past': 332,
#  'sunk': 333,
#  'curfew': 334,
#  'muslim': 335,
#  'tweet': 336,
#  'everything': 337,
#  'question': 338,
#  'kid': 339,
#  'theyre': 340,
#  'including': 341,
#  'middle': 342,
#  'plane': 343,
#  'moment': 344,
#  'play': 345,
#  'thousand': 346,
#  'hazard': 347,
#  'j': 348,
#  'saw': 349,
#  'black': 350,
#  'x': 351,
#  'dust': 352,
#  'bang': 353,
#  'derailment': 354,
#  'caused': 355,
#  'yesterday': 356,
#  'injured': 357,
#  'uk': 358,
#  'demolition': 359,
#  'better': 360,
#  'inside': 361,
#  'absolutely': 362,
#  'fight': 363,
#  'season': 364,
#  'british': 365,
#  'refugee': 366,
#  'island': 367,
#  'north': 368,
#  'local': 369,
#  'system': 370,
#  'risk': 371,
#  'survive': 372,
#  'along': 373,
#  'fan': 374,
#  'run': 375,
#  'panic': 376,
#  'following': 377,
#  'trapped': 378,
#  'dog': 379,
#  'destroy': 380,
#  'mudslide': 381,
#  'killing': 382,
#  'died': 383,
#  'stay': 384,
#  'hard': 385,
#  'avalanche': 386,
#  'campaign': 387,
#  'took': 388,
#  'court': 389,
#  'collided': 390,
#  'demolish': 391,
#  'young': 392,
#  'boy': 393,
#  'base': 394,
#  'ground': 395,
#  'food': 396,
#  'bushfire': 397,
#  'hand': 398,
#  'level': 399,
#  'crisis': 400,
#  'heat': 401,
#  'street': 402,
#  'public': 403,
#  'jan': 404,
#  'le': 405,
#  'small': 406,
#  'believe': 407,
#  'blew': 408,
#  'ready': 409,
#  'win': 410,
#  'bernie': 411,
#  'hell': 412,
#  'student': 413,
#  'screamed': 414,
#  'tornado': 415,
#  'group': 416,
#  'soldier': 417,
#  'trouble': 418,
#  'arson': 419,
#  'eye': 420,
#  'outside': 421,
#  'looking': 422,
#  'top': 423,
#  'huge': 424,
#  'taking': 425,
#  'spill': 426,
#  'side': 427,
#  'kind': 428,
#  'turn': 429,
#  'fucking': 430,
#  'yeah': 431,
#  'puerto': 432,
#  'wasnt': 433,
#  'whats': 434,
#  'seismic': 435,
#  'ok': 436,
#  'talk': 437,
#  'shes': 438,
#  'men': 439,
#  'reason': 440,
#  'sound': 441,
#  'affected': 442,
#  'problem': 443,
#  'wreck': 444,
#  'snowstorm': 445,
#  'word': 446,
#  'low': 447,
#  'ambulance': 448,
#  'maybe': 449,
#  'wildfire': 450,
#  'account': 451,
#  'wont': 452,
#  'natural': 453,
#  'panicking': 454,
#  'hazardous': 455,
#  'drought': 456,
#  'hitchin': 457,
#  'drowned': 458,
#  'traumatised': 459,
#  'vehicle': 460,
#  'east': 461,
#  'second': 462,
#  'e': 463,
#  'came': 464,
#  'major': 465,
#  'breaking': 466,
#  'outbreak': 467,
#  'book': 468,
#  'quarantined': 469,
#  'upheaval': 470,
#  'incident': 471,
#  'democrat': 472,
#  'event': 473,
#  'full': 474,
#  'running': 475,
#  'taken': 476,
#  'sick': 477,
#  'destroyed': 478,
#  'using': 479,
#  'clear': 480,
#  'follow': 481,
#  'deal': 482,
#  'idea': 483,
#  'ruin': 484,
#  'displaced': 485,
#  'county': 486,
#  'cliff': 487,
#  'freight': 488,
#  'reactor': 489,
#  'true': 490,
#  'dream': 491,
#  'number': 492,
#  'shooting': 493,
#  'late': 494,
#  'bring': 495,
#  'half': 496,
#  'soon': 497,
#  'warren': 498,
#  'poor': 499,
#  'destruction': 500,
#  'community': 501,
#  'heavy': 502,
#  'here': 503,
#  'bleeding': 504,
#  'care': 505,
#  'told': 506,
#  'wanted': 507,
#  'collide': 508,
#  'swallow': 509,
#  'demolished': 510,
#  'riot': 511,
#  'leave': 512,
#  'k': 513,
#  'driving': 514,
#  'wound': 515,
#  'action': 516,
#  'yall': 517,
#  'issue': 518,
#  'gun': 519,
#  'survived': 520,
#  'kill': 521,
#  'rescued': 522,
#  'scream': 523,
#  'fuck': 524,
#  'nation': 525,
#  'catastrophic': 526,
#  'lane': 527,
#  'eyewitness': 528,
#  'several': 529,
#  'as': 530,
#  'lol': 531,
#  'rico': 532,
#  'leader': 533,
#  'hey': 534,
#  'article': 535,
#  'wrong': 536,
#  'star': 537,
#  'hindu': 538,
#  'member': 539,
#  'blazing': 540,
#  'watching': 541,
#  'scene': 542,
#  'order': 543,
#  'deluge': 544,
#  'behind': 545,
#  'thinking': 546,
#  'protest': 547,
#  'understand': 548,
#  'single': 549,
#  'health': 550,
#  'tragedy': 551,
#  'town': 552,
#  'making': 553,
#  'imagine': 554,
#  'ask': 555,
#  'burn': 556,
#  'company': 557,
#  'control': 558,
#  'wait': 559,
#  'safe': 560,
#  'explosion': 561,
#  'river': 562,
#  'crush': 563,
#  'gove': 564,
#  'l': 565,
#  'picture': 566,
#  'living': 567,
#  'land': 568,
#  'feeling': 569,
#  'stand': 570,
#  'danger': 571,
#  'arrested': 572,
#  'nearly': 573,
#  'hijacker': 574,
#  'pakistan': 575,
#  'history': 576,
#  'wounded': 577,
#  'guess': 578,
#  'wild': 579,
#  'break': 580,
#  'nc': 581,
#  'quarantine': 582,
#  'security': 583,
#  'ukrainian': 584,
#  'resident': 585,
#  'else': 586,
#  'probably': 587,
#  'burned': 588,
#  'though': 589,
#  'plant': 590,
#  'front': 591,
#  'wildlife': 592,
#  'zone': 593,
#  'survivor': 594,
#  'hail': 595,
#  'razed': 596,
#  'completely': 597,
#  'future': 598,
#  'asking': 599,
#  'annihilated': 600,
#  'current': 601,
#  'strike': 602,
#  'helicopter': 603,
#  'law': 604,
#  'brace': 605,
#  'bridge': 606,
#  'ash': 607,
#  'player': 608,
#  'massive': 609,
#  'inundated': 610,
#  'inundation': 611,
#  'rescuer': 612,
#  'cannot': 613,
#  'within': 614,
#  'continue': 615,
#  'response': 616,
#  'regime': 617,
#  'co': 618,
#  'speak': 619,
#  'song': 620,
#  'music': 621,
#  'finally': 622,
#  'london': 623,
#  'red': 624,
#  'missing': 625,
#  'border': 626,
#  'bit': 627,
#  'strong': 628,
#  'likely': 629,
#  'door': 630,
#  'bomber': 631,
#  'situation': 632,
#  'sinking': 633,
#  'crashed': 634,
#  'trauma': 635,
#  'flooding': 636,
#  'hijacking': 637,
#  'triumphant': 638,
#  'west': 639,
#  'reported': 640,
#  'traffic': 641,
#  'aftershock': 642,
#  'working': 643,
#  'missile': 644,
#  'hate': 645,
#  'happened': 646,
#  'tonight': 647,
#  'vote': 648,
#  'movie': 649,
#  'islamic': 650,
#  'g': 651,
#  'govt': 652,
#  'piece': 653,
#  'kashmir': 654,
#  'bioterrorism': 655,
#  'ur': 656,
#  'lie': 657,
#  'sleep': 658,
#  'powerful': 659,
#  'monday': 660,
#  'mother': 661,
#  'information': 662,
#  'truck': 663,
#  'wish': 664,
#  'causing': 665,
#  'httpstco': 666,
#  'build': 667,
#  'pretty': 668,
#  'yo': 669,
#  'matter': 670,
#  'bts': 671,
#  'different': 672,
#  'collapsed': 673,
#  'responder': 674,
#  'crushed': 675,
#  'sandstorm': 676,
#  'obliterated': 677,
#  'violence': 678,
#  'apocalypse': 679,
#  'quality': 680,
#  'anything': 681,
#  'light': 682,
#  'currently': 683,
#  'ha': 684,
#  'united': 685,
#  'gt': 686,
#  'visit': 687,
#  'instead': 688,
#  'biggest': 689,
#  'sign': 690,
#  'business': 691,
#  'indian': 692,
#  'prayer': 693,
#  'serious': 694,
#  'sea': 695,
#  'comment': 696,
#  'arent': 697,
#  'park': 698,
#  'alone': 699,
#  'lead': 700,
#  'miss': 701,
#  'early': 702,
#  'bombed': 703,
#  'possible': 704,
#  'rise': 705,
#  'giving': 706,
#  'melbourne': 707,
#  'minister': 708,
#  'return': 709,
#  'total': 710,
#  'flame': 711,
#  'market': 712,
#  'harm': 713,
#  'dr': 714,
#  'beat': 715,
#  'sad': 716,
#  'minute': 717,
#  'happy': 718,
#  'cost': 719,
#  'die': 720,
#  'join': 721,
#  'donation': 722,
#  'station': 723,
#  'tuesday': 724,
#  'three': 725,
#  'center': 726,
#  'activity': 727,
#  'move': 728,
#  'act': 729,
#  'seems': 730,
#  'billion': 731,
#  'terrorism': 732,
#  'evacuation': 733,
#  'hijack': 734,
#  'gone': 735,
#  'latest': 736,
#  'continues': 737,
#  'crew': 738,
#  'hospital': 739,
#  'innocent': 740,
#  'sent': 741,
#  'list': 742,
#  'type': 743,
#  'effect': 744,
#  'listen': 745,
#  'protect': 746,
#  'crime': 747,
#  'parent': 748,
#  'pay': 749,
#  'result': 750,
#  'pedestrian': 751,
#  'hellfire': 752,
#  'rioting': 753,
#  'chinese': 754,
#  'region': 755,
#  'image': 756,
#  'political': 757,
#  'become': 758,
#  'gave': 759,
#  'hurt': 760,
#  'passenger': 761,
#  'leaving': 762,
#  'weve': 763,
#  'bc': 764,
#  'de': 765,
#  'bbc': 766,
#  'photo': 767,
#  'caught': 768,
#  'interview': 769,
#  'forced': 770,
#  'authority': 771,
#  'saudi': 772,
#  'worst': 773,
#  'ocean': 774,
#  'blight': 775,
#  'blizzard': 776,
#  'drive': 777,
#  'justice': 778,
#  'isi': 779,
#  'devastation': 780,
#  'safety': 781,
#  'landslide': 782,
#  'detonate': 783,
#  'wrecked': 784,
#  'meltdown': 785,
#  'jesus': 786,
#  'soul': 787,
#  'pray': 788,
#  'flight': 789,
#  'others': 790,
#  'weekend': 791,
#  'son': 792,
#  'enemy': 793,
#  'nice': 794,
#  'wonder': 795,
#  'cat': 796,
#  'king': 797,
#  'four': 798,
#  'room': 799,
#  'chief': 800,
#  'date': 801,
#  'ar': 802,
#  'sa': 803,
#  'normal': 804,
#  'couple': 805,
#  'snow': 806,
#  'till': 807,
#  'wanna': 808,
#  'virus': 809,
#  'wouldnt': 810,
#  'sunday': 811,
#  'wake': 812,
#  'crazy': 813,
#  'youve': 814,
#  'mom': 815,
#  'hold': 816,
#  'earth': 817,
#  'large': 818,
#  'expert': 819,
#  'civilian': 820,
#  'canadian': 821,
#  'stupid': 822,
#  'record': 823,
#  'usa': 824,
#  'election': 825,
#  'cry': 826,
#  'global': 827,
#  'sense': 828,
#  'important': 829,
#  'drop': 830,
#  'property': 831,
#  'talking': 832,
#  'held': 833,
#  'district': 834,
#  'joe': 835,
#  'backup': 836,
#  'bioterror': 837,
#  'cut': 838,
#  'mystery': 839,
#  'worse': 840,
#  'shut': 841,
#  'tour': 842,
#  'evacuate': 843,
#  'impact': 844,
#  'closed': 845,
#  'rd': 846,
#  'batangas': 847,
#  'ablaze': 848,
#  'longer': 849,
#  'central': 850,
#  'worker': 851,
#  'phone': 852,
#  'loss': 853,
#  'thread': 854,
#  'iraq': 855,
#  'waiting': 856,
#  'cover': 857,
#  'damn': 858,
#  'course': 859,
#  'havent': 860,
#  'couldnt': 861,
#  'short': 862,
#  'view': 863,
#  'pick': 864,
#  'share': 865,
#  'horse': 866,
#  'brother': 867,
#  'voice': 868,
#  'green': 869,
#  'failure': 870,
#  'lady': 871,
#  'evidence': 872,
#  'asked': 873,
#  'royal': 874,
#  'amazing': 875,
#  'telling': 876,
#  'bill': 877,
#  'close': 878,
#  'art': 879,
#  'dublin': 880,
#  'epicentre': 881,
#  'windstorm': 882,
#  'murderer': 883,
#  'walk': 884,
#  'either': 885,
#  'note': 886,
#  'soleimani': 887,
#  'father': 888,
#  'judge': 889,
#  'felt': 890,
#  'english': 891,
#  'claim': 892,
#  'tried': 893,
#  'fake': 894,
#  'annihilation': 895,
#  'film': 896,
#  'hundred': 897,
#  'singh': 898,
#  'forget': 899,
#  'able': 900,
#  'link': 901,
#  'agree': 902,
#  'dear': 903,
#  'thailand': 904,
#  'buy': 905,
#  'condition': 906,
#  'planet': 907,
#  'footage': 908,
#  'seeing': 909,
#  'entire': 910,
#  'speed': 911,
#  'bagging': 912,
#  'tree': 913,
#  'relief': 914,
#  'scared': 915,
#  'training': 916,
#  'calling': 917,
#  'coast': 918,
#  'volcanic': 919,
#  'thunder': 920,
#  'internet': 921,
#  'push': 922,
#  'dude': 923,
#  'process': 924,
#  'decided': 925,
#  'exactly': 926,
#  'send': 927,
#  'driver': 928,
#  'data': 929,
#  'httpst': 930,
#  'clearly': 931,
#  'deep': 932,
#  'given': 933,
#  'statement': 934,
#  'john': 935,
#  'sun': 936,
#  'russian': 937,
#  'la': 938,
#  'evil': 939,
#  'multiple': 940,
#  'ca': 941,
#  'benn': 942,
#  'sometimes': 943,
#  'sir': 944,
#  'horror': 945,
#  'western': 946,
#  'sleeping': 947,
#  'koala': 948,
#  'price': 949,
#  'est': 950,
#  'brendan': 951,
#  'stormbrendan': 952,
#  'rock': 953,
#  'office': 954,
#  'who': 955,
#  'per': 956,
#  'series': 957,
#  'despite': 958,
#  'study': 959,
#  'thanks': 960,
#  'whether': 961,
#  'policy': 962,
#  'stream': 963,
#  'rn': 964,
#  'firefighter': 965,
#  'research': 966,
#  'charge': 967,
#  'al': 968,
#  'tv': 969,
#  'liberal': 970,
#  'experienced': 971,
#  'abuse': 972,
#  'lvl': 973,
#  'towards': 974,
#  'facing': 975,
#  'eu': 976,
#  'mile': 977,
#  'round': 978,
#  'route': 979,
#  'together': 980,
#  'fatal': 981,
#  'melissa': 982,
#  'stone': 983,
#  'blue': 984,
#  'showing': 985,
#  'evening': 986,
#  'protester': 987,
#  'meet': 988,
#  'foot': 989,
#  'totally': 990,
#  'cool': 991,
#  'harry': 992,
#  'bed': 993,
#  'forecast': 994,
#  'experience': 995,
#  'happening': 996,
#  'answer': 997,
#  'drunk': 998,
#  'university': 999,
#  'journalist': 1000,
#  ...}

# %%
len(vocab_size)
# Out:
# 25194

# %%
X2 = tokenizer.texts_to_sequences(df1['text_clean'].values)
#texts_to_sequences: Transforms each text in texts to a sequence of integers. 
    #So it basically takes each word in the text and replaces it with its corresponding integer value from the word_index dictionary. 
    #Nothing more, nothing less, certainly no magic involved.

# %%
X2
# Out:
# [[678, 1478, 1550, 983, 335, 71, 71, 460, 158, 848],
#  [1550, 2073, 1478, 215, 2258, 1752, 35, 416, 215, 1308],
#  [1137, 158, 188, 848],
#  [1137, 158, 188, 848],
#  [1138, 786, 59, 1753, 1309, 1479, 158, 106, 848, 565],
#  [125, 754, 336, 18, 735, 2259, 1086, 189, 18, 848, 18, 111, 1251, 348],
#  [529, 71, 158, 848, 1139, 1901, 368, 639, 755, 2499],
#  [1551, 954, 1139, 158, 848, 52, 132, 1551, 545, 471, 70, 107],
#  [320, 583, 708, 427, 158, 921, 848, 736, 659, 100],
#  [955, 787, 8, 849, 984, 848, 76, 1754, 1754],
#  [756, 985, 355, 2499, 165, 71, 165, 640],
#  [1086, 189, 321, 660, 986, 244, 709],
#  [1651, 158, 116, 954, 369, 1252, 1902, 116, 848, 116, 954],
#  [757, 678, 2, 737, 639, 954],
#  [158, 301, 370, 848, 33],
#  [756, 985, 355, 2499, 165, 71, 165],
#  [8, 24, 369, 2074, 29, 848],
#  [158, 106, 848, 267, 1755, 146],
#  [848, 47, 986],
#  [2260, 158, 71, 848, 35, 392, 393, 56, 1756, 382],
#  [2499, 417, 1139, 1757, 848, 710],
#  [5, 848, 679, 58, 79, 58, 302],
#  [1903, 150, 1903, 226],
#  [884, 5, 1, 711, 1, 158, 848, 1758],
#  [1904, 1087, 738, 1087],
#  [1652, 1038, 128, 418, 158, 848],
#  [85, 419, 356, 158, 848, 1252, 79, 77],
#  [85, 403, 712, 2075, 158, 848, 62, 758],
#  [428, 490, 2074],
#  [2076, 158, 34, 848],
#  [1480, 660, 404, 48, 987, 158, 1759, 848],
#  [1480, 660, 404, 48, 987, 158, 1759, 848],
#  [429, 420, 1757, 848, 71, 147],
#  [59, 597, 813, 814, 430, 491, 3, 12, 2077],
#  [1310, 105, 1193, 4, 613, 283, 235, 713],
#  [1311, 708, 714, 1140, 714, 1481],
#  [197, 1088, 321, 988, 357, 185, 739, 2261, 31],
#  [759, 6, 337, 989, 9],
#  [431, 16, 129, 93, 185, 3, 990],
#  [991, 15, 922, 17],
#  [24, 1653, 383, 885],
#  [32, 1760, 29, 2262, 185],
#  [295, 1395, 992, 1482, 661, 2263, 27, 1, 185],
#  [180, 1, 1818, 221, 2259],
#  [700, 338, 1488, 1018, 1696, 1099],
#  [15, 291, 1600, 682, 868],
#  [626, 2137, 1280, 2340, 837, 114],
#  [222, 744, 2140, 1231, 299, 207],
#  [222, 744, 2140, 1231, 299, 207],
#  [1342],
#  [626, 2137, 2340, 1280, 837, 1155, 550],
#  [626, 2137, 2340, 1280, 655, 114],
#  [837, 773],
#  [626, 2137, 2340, 1280, 837],
#  [626, 2137, 2340, 1280, 837, 114],
#  [626, 2137, 2340, 1280, 837, 114],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [1969, 116, 2341, 655, 205, 837],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [180, 1, 1818, 221, 2259],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [28, 1232, 210, 1820, 79, 1601],
#  [338, 1962, 961, 77, 933, 809],
#  [968, 284, 819, 837],
#  [1602, 1514, 308, 20, 1651, 2141, 1281],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [905, 2142, 837, 82],
#  [1211, 837, 2140],
#  [1819, 837, 473],
#  [837, 477, 2, 958, 1437],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473, 114, 265],
#  [143, 585, 939, 2300, 837, 43, 273, 172, 1211],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [441, 3, 85, 974, 1437],
#  [922, 98, 1437, 129, 1438, 837, 473, 180],
#  [922, 1437, 129, 1819, 837, 473],
#  [1342, 535, 1358, 288, 1098],
#  [922, 1437, 129, 1819, 837, 473],
#  [922, 98, 1437, 129, 1438, 1819, 837, 473],
#  [1970, 2289, 2342, 2342, 1821],
#  [363, 655, 1439, 15, 57, 1937, 13, 1697],
#  [363, 655, 944],
#  [363, 655, 1439, 15, 57, 1937, 13, 1697],
#  [205, 244, 655, 1507, 1070, 614, 501],
#  [885, 81, 1515, 256, 655],
#  [794, 303, 1268, 655],
#  [219, 672, 84, 341, 453, 84, 94, 655],
#  [148, 405, 655, 63, 516, 1603],
#  [960, 1941, 1019, 655, 604, 327, 1440, 1019],
#  [627, 682, 1233],
#  [339, 44, 1971, 107, 1233, 689, 467, 11],
#  [441, 3, 153, 467, 153, 655, 205],
#  [1972, 2343, 1359, 3, 531, 2344, 655, 726],
#  [41, 655, 9, 483],
#  [1218, 655],
#  [1218, 655],
#  [655, 233, 1973, 213, 1437, 95, 524],
#  [13, 529, 583, 1416, 1172],
#  [655],
#  [2099, 655],
#  [1216, 1974],
#  [655],
#  [148, 405, 655, 63, 516],
#  [1173, 727, 1198, 655, 2143, 1070, 33, 827, 18],
#  [257, 2140, 655],
#  [1698, 1441, 1056, 1934, 2112],
#  [569, 429, 1430, 655, 2, 231],
#  [14, 1269, 655],
#  [655, 665, 572, 897, 1137, 1757, 5],
#  [224, 108, 1906, 655],
#  [655, 689, 127],
#  [1970, 2289, 2342, 2342, 2289],
#  [1418, 655, 803, 70, 1931, 1174, 1039],
#  [1553, 14, 1269, 655],
#  [569, 429, 1430, 655, 2],
#  [339, 10, 655, 220, 10, 1360, 286],
#  [109, 19, 57, 277, 102],
#  [1970, 2289, 2342, 2342, 2289],
#  [655],
#  [1604, 655, 819],
#  [616, 1331, 216, 49, 13, 34, 975, 424, 216, 226],
#  [58, 1311],
#  [1569, 597, 1113, 1282, 116],
#  [1282, 79, 1115, 1822],
#  [814, 1282, 351],
#  [1282, 1020, 230],
#  [1983, 1158, 1432, 1235, 958, 504, 1105, 1178],
#  [2131, 6, 136, 504, 3, 317],
#  ...]

# %%
X2 = pad_sequences(X2)#pad_sequences is used to ensure that all sequences in a list have the same length.

# %%
X2.shape#overall shape of x
# Out:
# (11370, 21)

# %%
#More explanation of .fit_on_texts and .texts_to_sequences on belwo link

#https://stackoverflow.com/questions/51956000/what-does-keras-tokenizer-method-exactly-do

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, SpatialDropout1D

# %%
embed_dim = 128
lstm_out = 196

model = Sequential()
model.add(Embedding(vocabSize, embed_dim,input_length = X2.shape[1]))
#vocabSize:input_dim (Integer. Size of the vocabulary, i.e. maximum integer index + 1.)
#embed_dim:output_dim (Integer. Dimension of the dense embedding.)
#input_length: Length of input sequences
model.add(SpatialDropout1D(0.4))#explained below
model.add(LSTM(lstm_out, dropout=0.2, recurrent_dropout=0.2))
#lstm_out : Positive integer, dimensionality of the output space.
model.add(Dense(2,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 21, 128)           320000
# _________________________________________________________________
# spatial_dropout1d (SpatialDr (None, 21, 128)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 196)               254800
# _________________________________________________________________
# dense (Dense)                (None, 2)                 394
# =================================================================
# Total params: 575,194
# Trainable params: 575,194
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#What is SpatialDropout1D?

# %%
#Dropout(): Let's define 2D input: [[1, 1, 1], [2, 2, 2]]. 
            #Dropout will consider every element independently, and may result in something like [[1, 0, 1], [0, 2, 2]]
    
#SpatialDropout1D(): In this case result will look like [[1, 0, 1], [2, 0, 2]]. 
                    #Notice that 2nd element was zeroed along all channels.

# %%
from sklearn.model_selection import train_test_split

Y2 = pd.get_dummies(df1['target']).values
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2,Y2, test_size = 0.15, random_state = 42)
print(X_train2.shape,Y_train2.shape)
print(X_test2.shape,Y_test2.shape)
# Out:
# (9664, 21) (9664, 2)
# (1706, 21) (1706, 2)

# %%
batch_size = 40
model.fit(X_train2, Y_train2, epochs = 10, batch_size=batch_size, verbose = 1)
# Out:
# Epoch 1/10
# 242/242 [==============================] - 36s 115ms/step - loss: 0.3842 - accuracy: 0.8431
# Epoch 2/10
# 242/242 [==============================] - 27s 112ms/step - loss: 0.2536 - accuracy: 0.9036
# Epoch 3/10
# 242/242 [==============================] - 30s 124ms/step - loss: 0.2166 - accuracy: 0.9173
# Epoch 4/10
# 242/242 [==============================] - 30s 123ms/step - loss: 0.1870 - accuracy: 0.9280
# Epoch 5/10
# 242/242 [==============================] - 31s 127ms/step - loss: 0.1593 - accuracy: 0.9396
# Epoch 6/10
# 242/242 [==============================] - 30s 125ms/step - loss: 0.1370 - accuracy: 0.9487
# Epoch 7/10
# 242/242 [==============================] - 30s 125ms/step - loss: 0.1139 - accuracy: 0.9578
# Epoch 8/10
# 242/242 [==============================] - 33s 136ms/step - loss: 0.1005 - accuracy: 0.9623
# Epoch 9/10
# 242/242 [==============================] - 34s 140ms/step - loss: 0.0883 - accuracy: 0.9674
# Epoch 10/10
# 242/242 [==============================] - 30s 126ms/step - loss: 0.0742 - accuracy: 0.9722

# %%
score,acc = model.evaluate(X_test2, Y_test2, verbose = 1, batch_size = batch_size)
print("score: %.2f" % (score))
print("accuracy: %.2f" % (acc))
# Out:
# 43/43 [==============================] - 2s 25ms/step - loss: 0.4974 - accuracy: 0.8681 0s - loss: 0.464
# score: 0.50
# accuracy: 0.87

# %%
#---------------------------------------------------END--------------------------------------------------------------------------------#
